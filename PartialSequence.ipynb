# %%
class Vowels:
    def __getitem__(self, i):
        return 'SHANTI'[i]

v = Vowels()

print(v[0])
print(v[1])
print(v[2])
# Out:
# S
# H
# A

# %%
for c in v: print(c)
# Out:
# S
# H
# A
# N
# T
# I

# %%
'S' in v
# Out:
# True

# %%
'w'in v
# Out:
# False
